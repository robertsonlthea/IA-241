# %% [markdown]
# # Analyzing COVID-19 Data in Countries with the Least Cases

# %% [markdown]
# ## Background

# %% [markdown]
# On 9 January 2020, WHO announced the beginning of the COVID-19 pandemic with the discovery of a mysterious corona-virus related pneumonia in Wuhan, China. As of the end of 2020, the United States surpassed 20 million infections from SARS-CoV-2, and more than 346,000 deaths. Globally, cases rose to 83,832,334 and 1,824,590 deaths.

# %% [markdown]
# ## Data Source

# %% [markdown]
# The data was downloaded from the [European Centre for Disease Prevention and Control](https://www.ecdc.europa.eu/en/publications-data/download-todays-data-geographic-distribution-covid-19-cases-worldwide)

# %%
# %matplotlib inline
import pandas

# %% [markdown]
# ## An Overview of the COVID-19 Data

# %%
df = pandas.read_excel('s3://robertson-ia241-2021spring/COVID-19-geographic-disbtribution-worldwide-2020-12-14 (1).xls')

df[:100]
# Out:
#       dateRep  day  month  year  cases  deaths countriesAndTerritories geoId  \
# 0  2020-12-14   14     12  2020    746       6             Afghanistan    AF
# 1  2020-12-13   13     12  2020    298       9             Afghanistan    AF
# 2  2020-12-12   12     12  2020    113      11             Afghanistan    AF
# 3  2020-12-11   11     12  2020     63      10             Afghanistan    AF
# 4  2020-12-10   10     12  2020    202      16             Afghanistan    AF
# ..        ...  ...    ...   ...    ...     ...                     ...   ...
# 95 2020-09-10   10      9  2020     24       2             Afghanistan    AF
# 96 2020-09-09    9      9  2020     26       3             Afghanistan    AF
# 97 2020-09-08    8      9  2020     96       3             Afghanistan    AF
# 98 2020-09-07    7      9  2020     74       2             Afghanistan    AF
# 99 2020-09-06    6      9  2020     20       0             Afghanistan    AF
#
# ...

# %% [markdown]
# ## Trend in the Number of Cases Per Day From January to December of 2020

# %%
sum_cases_per_day = df.groupby('dateRep').sum()['cases']

# %%
sum_cases_per_day.plot()
# Out:
# <AxesSubplot:xlabel='dateRep'>

# %% [markdown]
# ## Trend in the Number of Deaths Per Day From January to December of 2020

# %%
sum_deaths_per_day = df.groupby('dateRep').sum()['deaths']

# %%
sum_deaths_per_day.plot()
# Out:
# <AxesSubplot:xlabel='dateRep'>

# %% [markdown]
# ### Explanation of Calculations

# %% [markdown]
# Calculations were used to assess the total sum of cases and deaths per day in these two line charts by using df.groupby and grouping the x axis by the 'dateRep.'
#
# The .sum() was used to calculate total cases or deaths in each chart which is represented by the line on the chart.

# %% [markdown]
# ### Interpretation

# %% [markdown]
# There is an exponential growth in both cases and deaths from January of 2020 to December of 2020.

# %% [markdown]
# ## Countries with the Smallest Amount of COVID-19 Cases

# %%
sum_cases_per_country = df.groupby('countriesAndTerritories').sum()['cases']

# %%
sum_cases_per_country.nsmallest(10).plot.bar()
# Out:
# <AxesSubplot:xlabel='countriesAndTerritories'>

# %% [markdown]
# ### Explanation and Calculations

# %% [markdown]
# Calculations in this graphic were used to compare the total number of cases in the top 10 countries with the least amount of COVID-19 cases using df.grouby ('countriesAndTerritories') with .sum() of 'cases'

# %% [markdown]
# ### Implications

# %% [markdown]
# This bar chart shows that some countries were barely affected by the COVID-19 pandemic either due to strict regulations and quarantines or because of the countries geography

# %% [markdown]
# ## Vanuatu COVID-19 Data

# %%
vanuatu_data = df.loc[df['countriesAndTerritories']=='Vanuatu'] 
vanuatu_data[:100]
# Out:
#          dateRep  day  month  year  cases  deaths countriesAndTerritories  \
# 60165 2020-12-14   14     12  2020      0       0                 Vanuatu
# 60166 2020-12-13   13     12  2020      0       0                 Vanuatu
# 60167 2020-12-12   12     12  2020      0       0                 Vanuatu
# 60168 2020-12-11   11     12  2020      0       0                 Vanuatu
# 60169 2020-12-10   10     12  2020      0       0                 Vanuatu
# 60170 2020-12-09    9     12  2020      0       0                 Vanuatu
# 60171 2020-12-08    8     12  2020      0       0                 Vanuatu
# 60172 2020-12-07    7     12  2020      0       0                 Vanuatu
# 60173 2020-12-06    6     12  2020      0       0                 Vanuatu
# 60174 2020-12-05    5     12  2020      0       0                 Vanuatu
# 60175 2020-12-04    4     12  2020      0       0                 Vanuatu
# 60176 2020-12-03    3     12  2020      0       0                 Vanuatu
# ...

# %% [markdown]
# ## Number of Deaths in Relation to the Number of Cases in Vanuatu

# %%
vanuatu_data.plot.scatter(x='cases',y='deaths',c='month')
# Out:
# <AxesSubplot:xlabel='cases', ylabel='deaths'>

# %% [markdown]
# ## Wallis and Futuna COVID-19 Data

# %%
wallis_and_futuna_data = df.loc[df['countriesAndTerritories']=='Wallis_and_Futuna'] 
wallis_and_futuna_data[:100]
# Out:
#          dateRep  day  month  year  cases  deaths countriesAndTerritories  \
# 60819 2020-12-14   14     12  2020      0       0       Wallis_and_Futuna
# 60820 2020-12-13   13     12  2020      0       0       Wallis_and_Futuna
# 60821 2020-12-12   12     12  2020      0       0       Wallis_and_Futuna
# 60822 2020-12-11   11     12  2020      0       0       Wallis_and_Futuna
# 60823 2020-12-10   10     12  2020      0       0       Wallis_and_Futuna
# 60824 2020-12-09    9     12  2020      0       0       Wallis_and_Futuna
# 60825 2020-12-08    8     12  2020      0       0       Wallis_and_Futuna
# 60826 2020-12-07    7     12  2020      0       0       Wallis_and_Futuna
# 60827 2020-12-06    6     12  2020      0       0       Wallis_and_Futuna
# 60828 2020-12-05    5     12  2020      0       0       Wallis_and_Futuna
# 60829 2020-12-04    4     12  2020      0       0       Wallis_and_Futuna
# 60830 2020-12-03    3     12  2020      0       0       Wallis_and_Futuna
# ...

# %% [markdown]
# ## Number of Deaths in Relation to the Number of Cases in Wallis and Futuna

# %%
wallis_and_futuna_data.plot.scatter(x='cases',y='deaths',c='month')
# Out:
# <AxesSubplot:xlabel='cases', ylabel='deaths'>

# %% [markdown]
# ## Marshall Islands COVID-19 Data

# %%
marshall_islands_data = df.loc[df['countriesAndTerritories']=='Marshall_Islands'] 
marshall_islands_data[:100]
# Out:
#          dateRep  day  month  year  cases  deaths countriesAndTerritories  \
# 36378 2020-12-14   14     12  2020      0       0        Marshall_Islands
# 36379 2020-12-13   13     12  2020      0       0        Marshall_Islands
# 36380 2020-12-12   12     12  2020      0       0        Marshall_Islands
# 36381 2020-12-11   11     12  2020      0       0        Marshall_Islands
# 36382 2020-12-10   10     12  2020      0       0        Marshall_Islands
# 36383 2020-12-09    9     12  2020      0       0        Marshall_Islands
# 36384 2020-12-08    8     12  2020      0       0        Marshall_Islands
# 36385 2020-12-07    7     12  2020      0       0        Marshall_Islands
# 36386 2020-12-06    6     12  2020      0       0        Marshall_Islands
# 36387 2020-12-05    5     12  2020      0       0        Marshall_Islands
# 36388 2020-12-04    4     12  2020      0       0        Marshall_Islands
# 36389 2020-12-03    3     12  2020      0       0        Marshall_Islands
# ...

# %% [markdown]
# ## Number of Deaths in Relation to the Number of Cases in the Marshall Islands

# %%
marshall_islands_data.plot.scatter(x='cases',y='deaths',c='month')
# Out:
# <AxesSubplot:xlabel='cases', ylabel='deaths'>

# %% [markdown]
# ## Anguilla COVID-19 Data

# %%
anguilla_data = df.loc[df['countriesAndTerritories']=='Anguilla'] 
anguilla_data[:100]
# Out:
#         dateRep  day  month  year  cases  deaths countriesAndTerritories  \
# 1510 2020-12-14   14     12  2020      0       0                Anguilla
# 1511 2020-12-13   13     12  2020      0       0                Anguilla
# 1512 2020-12-12   12     12  2020      0       0                Anguilla
# 1513 2020-12-11   11     12  2020      0       0                Anguilla
# 1514 2020-12-10   10     12  2020      0       0                Anguilla
# ...         ...  ...    ...   ...    ...     ...                     ...
# 1605 2020-09-10   10      9  2020      0       0                Anguilla
# 1606 2020-09-09    9      9  2020      0       0                Anguilla
# 1607 2020-09-08    8      9  2020      0       0                Anguilla
# 1608 2020-09-07    7      9  2020      0       0                Anguilla
# 1609 2020-09-06    6      9  2020      0       0                Anguilla
#
#      geoId countryterritoryCode  popData2019 continentExp  \
# ...

# %% [markdown]
# ## Number of Deaths in Relation to the Number of Cases in Anguilla

# %%
anguilla_data.plot.scatter(x='cases',y='deaths',c='month')
# Out:
# <AxesSubplot:xlabel='cases', ylabel='deaths'>

# %% [markdown]
# ## Montserrat COVID-19 Data

# %%
montserrat_data = df.loc[df['countriesAndTerritories']=='Anguilla'] 
montserrat_data[:100]
# Out:
#         dateRep  day  month  year  cases  deaths countriesAndTerritories  \
# 1510 2020-12-14   14     12  2020      0       0                Anguilla
# 1511 2020-12-13   13     12  2020      0       0                Anguilla
# 1512 2020-12-12   12     12  2020      0       0                Anguilla
# 1513 2020-12-11   11     12  2020      0       0                Anguilla
# 1514 2020-12-10   10     12  2020      0       0                Anguilla
# ...         ...  ...    ...   ...    ...     ...                     ...
# 1605 2020-09-10   10      9  2020      0       0                Anguilla
# 1606 2020-09-09    9      9  2020      0       0                Anguilla
# 1607 2020-09-08    8      9  2020      0       0                Anguilla
# 1608 2020-09-07    7      9  2020      0       0                Anguilla
# 1609 2020-09-06    6      9  2020      0       0                Anguilla
#
#      geoId countryterritoryCode  popData2019 continentExp  \
# ...

# %% [markdown]
# ## Number of Deaths in Relation to the Number of Cases in Montserrat

# %%
montserrat_data.plot.scatter(x='cases',y='deaths',c='month')
# Out:
# <AxesSubplot:xlabel='cases', ylabel='deaths'>

# %% [markdown]
# ### Explanation of Calculations

# %% [markdown]
# The calculations used in the above five scatter plots show the number of deaths related to the number of cases in each country by using the country's data which was singled out by defining a countries data using countryname_data = df.loc and then specifying the country's name after using 'CountriesAndTerritories' inside closed brackets. The scatter plots were then created by taking that specified data and adding .scatter(x='cases', y='deaths', c='month')

# %% [markdown]
# ### Implications

# %% [markdown]
# The scatter plots shown for the top 10 countries with the least amount of COVID-19 cases have very few points as a direct result of these countries having very few cases. This result is to be expected as trends cannot be drawn for number of deaths in relation to COVID-19 cases if there are no deaths or cases to compare within a country.

# %% [markdown]
# # Comparison to a Country with the Highest Number of Cases

# %%
sum_cases_per_country = df.groupby('countriesAndTerritories').sum()['cases']

# %%
sum_cases_per_country.nlargest(10).plot.bar()
# Out:
# <AxesSubplot:xlabel='countriesAndTerritories'>

# %% [markdown]
# ## U.S. COVID-19 Data

# %%
usa_data = df.loc[df['countriesAndTerritories']=='United_States_of_America'] 
usa_data[:100]
# Out:
#          dateRep  day  month  year   cases  deaths   countriesAndTerritories  \
# 59001 2020-12-14   14     12  2020  189723    1340  United_States_of_America
# 59002 2020-12-13   13     12  2020  216017    2315  United_States_of_America
# 59003 2020-12-12   12     12  2020  234633    3343  United_States_of_America
# 59004 2020-12-11   11     12  2020  224680    2748  United_States_of_America
# 59005 2020-12-10   10     12  2020  220025    3124  United_States_of_America
# ...          ...  ...    ...   ...     ...     ...                       ...
# 59096 2020-09-10   10      9  2020   31927    1136  United_States_of_America
# 59097 2020-09-09    9      9  2020   27122     471  United_States_of_America
# 59098 2020-09-08    8      9  2020   24250     267  United_States_of_America
# 59099 2020-09-07    7      9  2020   30555     403  United_States_of_America
# 59100 2020-09-06    6      9  2020   44140     773  United_States_of_America
#
# ...

# %% [markdown]
# ## Number of Deaths in Relation to the Number of Cases in the U.S.

# %%
usa_data.plot.scatter(x='cases',y='deaths',c='month')
# Out:
# <AxesSubplot:xlabel='cases', ylabel='deaths'>

# %% [markdown]
# ### Explanation of Calculations

# %% [markdown]
# As a contrast to those countries with the least amount of COVID-19 cases, the United States was used as it is the country with the greatest amount of COVID-19 cases. The data charts and scatter plots were created in the exact same way as those for Vanuatu, Wallis and Futuna, the Marshall Islands, Anguilla, and Montserrat.

# %% [markdown]
# ### Implicatons

# %% [markdown]
# The population of the United States in comparison to the countries with the least amount of COVID-19 cases is much higher. These countries also have significantly different geographies than the U.S. and have limited ports for transportation.

# %% [markdown]
# ## Author Information

# %% [markdown]
# Analyst: Theadora Robertson
#
# Email: rober6tl@dukes.jmu.edu

# %% [markdown]
# ## Conclusion

# %% [markdown]
# The limitations present within this assessment were that the analyst had a limited knowledge on certain countries outside of the United States, and they were also limited by the visualizations made after analysis as the five countries analyzed with the least amount of COVID-19 cases had scatter plots with few to no points.
#
# An improvement that could have been made to this project would have been to look at a specific country and compare it to that of the United States in order to see how the number of cases in relation to the number of deaths would change between the two.
